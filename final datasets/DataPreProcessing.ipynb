# %% [markdown]
# In this notebook we clean and uniform all the 5 datasets then used for the PhoneWorld application.
# The final result is composed by 3 datasets: Reviews.csv, Phones.csv and Users.csv.
#
# All the notebook is completely executable because takes the original raw datasets directly from git.
#
# To reload datasets, if needed, use the url of the files in the raw datasets folder at this link:
# https://github.com/FrankMartoccia/phoneworld

# %% [markdown]
# # Settings

# %%
#libraries
import pandas as pd

# %%
#set data dysplaying without truncating anything
#pd.set_option('display.max_colwidth', None)

# %%
#set data displaying options back to default
#pd.reset_option('^display.', silent=True)

# %% [markdown]
# # 20191226-items.csv

# %%
#load dataset
df_items = pd.read_csv('https://raw.githubusercontent.com/FrankMartoccia/phoneworld/master/raw%20datasets/20191226-items.csv?token=GHSAT0AAAAAABPN5LTAALMC44OSLQFTPLHIYPQGAYA')
df_items.head()
# Out:
#          asin     brand  ...   price originalPrice
# 0  B0000SX2UC       NaN  ...    0.00           0.0
# 1  B0009N5L7K  Motorola  ...   49.95           0.0
# 2  B000SKTZ0S  Motorola  ...   99.99           0.0
# 3  B001AO4OUC  Motorola  ...    0.00           0.0
# 4  B001DCJAJG  Motorola  ...  149.99           0.0
#
# [5 rows x 10 columns]

# %%
df_items.info()
#notice 4 null values for brand column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   asin           720 non-null    object
#  1   brand          716 non-null    object
#  2   title          720 non-null    object
#  3   url            720 non-null    object
#  4   image          720 non-null    object
#  5   rating         720 non-null    float64
#  6   reviewUrl      720 non-null    object
#  7   totalReviews   720 non-null    int64
#  8   price          720 non-null    float64
#  9   originalPrice  720 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 56.4+ KB

# %%
#control if there are any duplicates (controls if there are any rows with exactly the same values)
#if the df is empty, no row is equal to another one
df_items[df_items.duplicated()]
# Out:
# Empty DataFrame
# Columns: [asin, brand, title, url, image, rating, reviewUrl, totalReviews, price, originalPrice]
# Index: []

# %%
#try to fill the 4 rows where brand property is null
df_items[df_items['brand'].isnull()]
# Out:
#            asin brand  ...   price originalPrice
# 0    B0000SX2UC   NaN  ...    0.00           0.0
# 144  B01EWKHIAI   NaN  ...  242.99           0.0
# 471  B07JHXX5YR   NaN  ...  549.00         599.0
# 631  B07T3KMJW8   NaN  ...   99.99           0.0
#
# [4 rows x 10 columns]

# %%
df_items[df_items['brand'].isnull()].url
#remember to run the snippet in settings to not truncate data values in order to have complete url link
# Out:
# 0      https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 144    https://www.amazon.com/Microsoft-Lumia-RM-1118...
# 471    https://www.amazon.com/ROG-Phone-Gaming-Smartp...
# 631    https://www.amazon.com/Redmi-7A-16Gb-Black-EU/...
# Name: url, dtype: object

# %%
#two brands are all caps lock, they are incompatible with brand column in df_devices
df_items.brand = df_items.brand.replace({'ASUS': 'Asus'})
df_items.brand = df_items.brand.replace({'HUAWEI': 'Huawei'})

# %%
df_items.brand[0] = 'Nokia'
df_items.brand[144] = 'Nokia' #all Lumia phones are under Nokia brand and not Microsoft
df_items.brand[471] = 'Asus'
df_items.brand[631] = 'Xiaomi'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#rename some columns to uniform language between different datasets
df_items = df_items.rename(columns={'title': 'phoneName'})

# %%
#let's see how many brands are in the dataset just showing one time each brand
df_items.brand.drop_duplicates()
#10 brands
# Out:
# 0         Nokia
# 1      Motorola
# 6       Samsung
# 46       Huawei
# 71         Sony
# 92        Apple
# 169      Google
# 345        Asus
# 400     OnePlus
# 409      Xiaomi
# Name: brand, dtype: object

# %%
#analyze some strange things noticed...they can be noisy data
df_items[df_items['phoneName'].str.contains("Modem")]
# Out:
#            asin   brand  ...  price originalPrice
# 319  B0776ZJ1C3  Huawei  ...  24.50           0.0
# 555  B07PW9XW1G  Huawei  ...  79.99           0.0
#
# [2 rows x 10 columns]

# %%
df_items[df_items['phoneName'].str.contains("Router")]
# Out:
#            asin   brand  ... price originalPrice
# 365  B079TZVTNQ  Huawei  ...  49.9           0.0
# 387  B07C8H8G4L  Huawei  ...  78.9           0.0
#
# [2 rows x 10 columns]

# %%
df_items[df_items['phoneName'].str.contains("Hotspot")]
# Out:
#            asin     brand  ...   price originalPrice
# 365  B079TZVTNQ    Huawei  ...   49.90           0.0
# 387  B07C8H8G4L    Huawei  ...   78.90           0.0
# 678  B07XVMYN2N  Motorola  ...  134.98           0.0
#
# [3 rows x 10 columns]

# %%
#looking the url we notice that row 319, 555, 365, 387 are modem wifi, not smartphones so we drop them
#row 678 instead is a motorola phone so we keep it
df_items = df_items.drop(df_items.index[[319, 365, 387, 555]])

# %%
#now search for zero values in price column
df_items.originalPrice.value_counts()
# Out:
# 0.00      596
# 299.99      7
# 249.99      5
# 499.99      5
# 349.99      5
#          ...
# 429.99      1
# 139.99      1
# 699.95      1
# 339.99      1
# 949.99      1
# Name: originalPrice, Length: 90, dtype: int64

# %%
#drop useless columns. Price columns are dropped because contain too many zero values.
df_items = df_items.drop(columns = ['image', 'rating', 'url', 'reviewUrl', 'totalReviews', 'price', 'originalPrice'])

# %% [markdown]
# # 20191226-reviews.csv

# %%
#load dataset
df_reviews = pd.read_csv('https://raw.githubusercontent.com/FrankMartoccia/phoneworld/master/raw%20datasets/20191226-reviews.csv?token=GHSAT0AAAAAABPN5LTAOQF6LLIIJDZ3HOA6YPQGBFA')
df_reviews.head()
# Out:
#          asin  ... helpfulVotes
# 0  B0000SX2UC  ...          1.0
# 1  B0000SX2UC  ...         17.0
# 2  B0000SX2UC  ...          5.0
# 3  B0000SX2UC  ...          1.0
# 4  B0000SX2UC  ...          1.0
#
# [5 rows x 8 columns]

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67986 entries, 0 to 67985
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   asin          67986 non-null  object
#  1   name          67984 non-null  object
#  2   rating        67986 non-null  int64
#  3   date          67986 non-null  object
#  4   verified      67986 non-null  bool
#  5   title         67972 non-null  object
#  6   body          67965 non-null  object
#  7   helpfulVotes  27215 non-null  float64
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 3.7+ MB

# %%
#control if there are any duplicates (control if there are any rows with exactly the same values)
df_reviews[df_reviews.duplicated()]
# Out:
#              asin  ... helpfulVotes
# 2527   B00836Y6B2  ...          NaN
# 3047   B00836Y6B2  ...          NaN
# 3073   B00836Y6B2  ...          NaN
# 6985   B00E6FGSHY  ...          NaN
# 8378   B00F2SKPIM  ...          1.0
# 14917  B00OZTSY6Y  ...          1.0
# 15628  B00V7FY44A  ...          NaN
# 18163  B014GCG150  ...          NaN
# 27123  B01M0PADR4  ...          2.0
# 33455  B06XYMCMHD  ...          3.0
# 53176  B07HK4JNV1  ...          NaN
# 66713  B07WSJYDXX  ...          NaN
#
# [12 rows x 8 columns]

# %%
#drop the 12 duplicated rows
df_reviews = df_reviews.drop_duplicates()

# %%
#drop useless columns. Verified column is useless for our purpose.
#name column is dropped because for each review we will properly assign a fake user from the users dataset.
#helpful_votes has so much NaN values
df_reviews = df_reviews.drop(columns = ['verified', 'name', 'helpfulVotes'])

# %%
#convert to datetime the date column
df_reviews['date'] = pd.to_datetime(df_reviews['date'])

# %%
#rename some columns
df_reviews = df_reviews.rename(columns={'date': 'review_date', 'title': 'review_title', 'body': 'review_body'})

# %%
#let's see how are rows with NaN value on body and/or title
df_reviews[df_reviews['review_body'].isnull()]
#21 review_body NaN values
# Out:
#              asin  rating  ...                        review_title review_body
# 9445   B00HPP3QD6       5  ...                          Five Stars         NaN
# 18055  B013XAPUW6       2  ...               The Wrong Phone Color         NaN
# 19749  B018OMP8ES       2  ...               The Wrong Phone Color         NaN
# 20892  B01CJ3SCJ6       1  ...  DON'T BUY FROM CLEAN ELECTRIC!!!!!         NaN
# 21149  B01CJ3SF02       1  ...             I regret this purchase!         NaN
# 21887  B01D1J9BGU       1  ...                            One Star         NaN
# 22917  B01DZ2CS4U       1  ...  DON'T BUY FROM CLEAN ELECTRIC!!!!!         NaN
# 29501  B01N9XOXCK       5  ...                                  Hi         NaN
# 30010  B01NB1KG8U       5  ...                                 NaN         NaN
# 35596  B071JP8XDJ       5  ...                    Love the camera!         NaN
# 36845  B072N3GKSM       1  ...                            One Star         NaN
# 43415  B077YTCMH9       5  ...                                  Hi         NaN
# 45899  B079X7DQ4Q       5  ...                                 NaN         NaN
# 46470  B07BHT4KGM       5  ...                                 NaN         NaN
# 51628  B07H8Q3C9T       5  ...                  Just what i needed         NaN
# 52176  B07HD3QC65       4  ...                         good so far         NaN
# 55171  B07K4V3364       4  ...                          Four Stars         NaN
# 57837  B07NWKP41X       5  ...                        Size Matters         NaN
# 61074  B07Q84DPZH       5  ...                                 NaN         NaN
# 62205  B07QP9R469       4  ...          Good phone for your buck..         NaN
# 64371  B07V5KS95Y       5  ...                                 NaN         NaN
#
# [21 rows x 5 columns]

# %%
df_reviews[df_reviews['review_title'].isnull()]
#14 review_title NaN values
# Out:
#              asin  ...                                        review_body
# 30010  B01NB1KG8U  ...                                                NaN
# 30949  B06XR1K6HR  ...                             Almost like pretty new
# 32883  B06XSF5C42  ...  Love this phone. Everything's worked great. So...
# 35016  B071H9KKKF  ...  Like the phone so far!!! Never had an expensiv...
# 42935  B077T4MVZ6  ...                                            Love it
# 45899  B079X7DQ4Q  ...                                                NaN
# 45905  B079X7DQ4Q  ...              I get that phone I needed ,, thanks .
# 46470  B07BHT4KGM  ...                                                NaN
# 46476  B07BHT4KGM  ...              I get that phone I needed ,, thanks .
# 50404  B07FZH9BGV  ...                                  Great phone...A++
# 58439  B07NZXXZB2  ...                             It was s good purchase
# 61074  B07Q84DPZH  ...                                                NaN
# 61329  B07Q84DPZH  ...                        It was okay no dislikes yet
# 64371  B07V5KS95Y  ...                                                NaN
#
# [14 rows x 5 columns]

# %%
#as they are not so much data we decide to drop them
#Because we notice some review_body content repetition we can consider these as noise (probably fake reviews)
#having reviews with these uncomplete data can be a problem for any sentiment analysis or for ml alghorithms
df_reviews = df_reviews.dropna()
#it drops 30 rows
#21 with NaN body (of which 5 also without title) and 9  only without title

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67944 entries, 0 to 67985
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   asin          67944 non-null  object
#  1   rating        67944 non-null  int64
#  2   review_date   67944 non-null  datetime64[ns]
#  3   review_title  67944 non-null  object
#  4   review_body   67944 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
df_reviews
# Out:
#              asin  ...                                        review_body
# 0      B0000SX2UC  ...  I had the Samsung A600 for awhile which is abs...
# 1      B0000SX2UC  ...  Due to a software issue between Nokia and Spri...
# 2      B0000SX2UC  ...  This is a great, reliable phone. I also purcha...
# 3      B0000SX2UC  ...  I love the phone and all, because I really did...
# 4      B0000SX2UC  ...  The phone has been great for every purpose it ...
# ...           ...  ...                                                ...
# 67981  B081H6STQQ  ...  I love the camera on this phone. The screen is...
# 67982  B081H6STQQ  ...  I've been an Xperia user for several years and...
# 67983  B081H6STQQ  ...                         buy one more for my cousin
# 67984  B081TJFVCJ  ...  Product looks and works like new. Very much re...
# 67985  B0825BB7SG  ...  I love the size and style of this phone. It is...
#
# [67944 rows x 5 columns]

# %%
# considerations to understand if there are fake reviews
#df_reviews.review_title[df_reviews.review_title.duplicated()]
#df_reviews.review_body[df_reviews.review_body.duplicated()]

# %% [markdown]
# # brands_csv.csv

# %%
#load dataset
df_brands = pd.read_csv('https://raw.githubusercontent.com/FrankMartoccia/phoneworld/master/raw%20datasets/brands_csv.csv?token=GHSAT0AAAAAABPN5LTAK3MQJFYQNZ6NGNI6YPQGBQA')
df_brands.head()
# Out:
#    RECORDS/id RECORDS/name  ...  RECORDS/created_at  RECORDS/updated_at
# 0           1        Nokia  ...   7/9/2021 12:33:57   7/9/2021 12:33:57
# 1           2      alcatel  ...   7/9/2021 12:34:38   7/9/2021 12:34:38
# 2           3      Benefon  ...   7/9/2021 12:35:17   7/9/2021 12:35:17
# 3           4      Samsung  ...   7/9/2021 12:35:31   7/9/2021 12:35:31
# 4           5   Mitsubishi  ...   7/9/2021 12:35:53   7/9/2021 12:35:53
#
# [5 rows x 6 columns]

# %%
df_brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RECORDS/id          116 non-null    int64
#  1   RECORDS/name        116 non-null    object
#  2   RECORDS/logo        0 non-null      float64
#  3   RECORDS/deleted_at  0 non-null      float64
#  4   RECORDS/created_at  116 non-null    object
#  5   RECORDS/updated_at  116 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.6+ KB

# %%
df_brands = df_brands.drop(columns = ['RECORDS/logo', 'RECORDS/deleted_at', 'RECORDS/updated_at', 'RECORDS/created_at'])

# %%
df_brands = df_brands.rename(columns = {'RECORDS/id': 'brand_id', 'RECORDS/name': 'brand'})

# %%
df_brands[df_brands.duplicated()]
#no duplicates, so there are 116 different brands.
# Out:
# Empty DataFrame
# Columns: [brand_id, brand]
# Index: []

# %%
df_brands
# Out:
#      brand_id       brand
# 0           1       Nokia
# 1           2     alcatel
# 2           3     Benefon
# 3           4     Samsung
# 4           5  Mitsubishi
# ..        ...         ...
# 111       112      Realme
# 112       113     Infinix
# 113       114       Tecno
# 114       115         TCL
# 115       116   Fairphone
#
# [116 rows x 2 columns]

# %% [markdown]
# # devices_csv.csv

# %%
#load dataset
df_devices = pd.read_csv('https://raw.githubusercontent.com/FrankMartoccia/phoneworld/master/raw%20datasets/devices_csv.csv?token=GHSAT0AAAAAABPN5LTAN55GQNOXZJF36B4MYPQGBZQ')
df_devices.head()
# Out:
#    RECORDS/id  ... RECORDS/updated_at
# 0           1  ...  7/9/2021 12:33:57
# 1           2  ...  7/9/2021 12:34:00
# 2           3  ...  7/9/2021 12:34:02
# 3           4  ...  7/9/2021 12:34:04
# 4           5  ...  7/9/2021 12:34:07
#
# [5 rows x 21 columns]

# %%
df_devices.info()
#almost half of devices don't have information for the chipset, but we keep it and treat NaN values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10633 entries, 0 to 10632
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORDS/id                  10633 non-null  int64
#  1   RECORDS/url_hash            10633 non-null  object
#  2   RECORDS/brand_id            10633 non-null  int64
#  3   RECORDS/name                10633 non-null  object
#  4   RECORDS/picture             10633 non-null  object
#  5   RECORDS/released_at         10633 non-null  object
#  6   RECORDS/body                10345 non-null  object
#  7   RECORDS/os                  10633 non-null  object
#  8   RECORDS/storage             10633 non-null  object
#  9   RECORDS/display_size        10633 non-null  object
#  10  RECORDS/display_resolution  10586 non-null  object
#  11  RECORDS/camera_pixels       10633 non-null  object
#  12  RECORDS/video_pixels        10416 non-null  object
#  13  RECORDS/ram                 10633 non-null  object
#  14  RECORDS/chipset             5560 non-null   object
#  15  RECORDS/battery_size        10633 non-null  object
#  16  RECORDS/battery_type        10588 non-null  object
#  17  RECORDS/specifications      10633 non-null  object
#  18  RECORDS/deleted_at          0 non-null      float64
#  19  RECORDS/created_at          10633 non-null  object
#  20  RECORDS/updated_at          10633 non-null  object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.7+ MB

# %%
#drop RECORDS/ on each attribute
df_devices.columns = df_devices.columns.str.replace('RECORDS/', '')

# %%
#we drop useless columns
df_devices = df_devices.drop(columns = ['id', 'url_hash', 'deleted_at','created_at', 'updated_at', 'specifications'])

# %%
#we rename columns
df_devices = df_devices.rename(columns = {'name': 'phoneName', 'body': 'dimensions', 'display_size': 'displaySize', 'display_resolution':'displayResolution', 'camera_pixels': 'cameraPixels',
                                          'video_pixels': 'videoPixels', 'battery_size':'batterySize', 'battery_type': 'batteryType' })

# %%
df_devices[df_devices.duplicated()]
#no exactly the same rows, so no duplicated rows
# Out:
# Empty DataFrame
# Columns: [brand_id, phoneName, picture, released_at, dimensions, os, storage, displaySize, displayResolution, cameraPixels, videoPixels, ram, chipset, batterySize, batteryType]
# Index: []

# %%
# NaN values in chipset and dimensions columns
df_devices = df_devices.fillna( 'NOT SPECIFIED')

# %%
df_devices.info()
#some columns are essentialy numbers but the actual type is object.
#Need to convert them and also handle with incorrect values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10633 entries, 0 to 10632
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_id           10633 non-null  int64
#  1   phoneName          10633 non-null  object
#  2   picture            10633 non-null  object
#  3   released_at        10633 non-null  object
#  4   dimensions         10633 non-null  object
#  5   os                 10633 non-null  object
#  6   storage            10633 non-null  object
#  7   displaySize        10633 non-null  object
#  8   displayResolution  10633 non-null  object
#  9   cameraPixels       10633 non-null  object
#  10  videoPixels        10633 non-null  object
#  11  ram                10633 non-null  object
#  12  chipset            10633 non-null  object
#  13  batterySize        10633 non-null  object
#  14  batteryType        10633 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ MB

# %%
#finally add the phoneId to df_devices
df_devices["phoneId"] = df_devices.index + 1
df_devices
# Out:
#        brand_id           phoneName  ... batteryType phoneId
# 0             1          Nokia 3210  ...      Li-Ion       1
# 1             1          Nokia 5110  ...       Li-Po       2
# 2             1          Nokia 6110  ...       Li-Po       3
# 3             1          Nokia 6130  ...       Li-Po       4
# 4             1          Nokia 6150  ...       Li-Po       5
# ...         ...                 ...  ...         ...     ...
# 10628        98            vivo S7t  ...       Li-Po   10629
# 10629         6     Motorola Edge S  ...       Li-Po   10630
# 10630        62     ZTE Blade X1 5G  ...      Li-Ion   10631
# 10631        10     Sony Xperia Pro  ...       Li-Po   10632
# 10632         4  Samsung Galaxy A02  ...       Li-Po   10633
#
# [10633 rows x 16 columns]

# %%
# strange values in displaySize, ram, batterySize
#df_devices[df_devices.displaySize.str.contains('&nbsp;')]
#df_devices = df_devices.replace('&nbsp;', 'NOT SPECIFIED', inplace=True)
#df_devices.ram = df_devices.ram.replace('&nbsp;', 'NO', inplace=True)
#df_devices.batterySize = df_devices.batterySize.replace('&nbsp;', 'oooooooooooooooooo')

# %% [markdown]
# # users_csv.csv

# %%
#load dataset
df_users = pd.read_csv('https://raw.githubusercontent.com/FrankMartoccia/phoneworld/master/raw%20datasets/users_csv.csv?token=GHSAT0AAAAAABPN5LTBH6SIGU75RJFRVRZWYPQGCCQ')
df_users.head()
# Out:
#   results/gender results/name/title  ... results/registered/age results/nat
# 0           male                 Mr  ...                     19          ES
# 1         female                Mrs  ...                     15          NL
# 2         female                Mrs  ...                      6          NZ
# 3           male                 Mr  ...                     16          NZ
# 4           male                 Mr  ...                     18          IR
#
# [5 rows x 27 columns]

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   results/gender                          50000 non-null  object
#  1   results/name/title                      50000 non-null  object
#  2   results/name/first                      50000 non-null  object
#  3   results/name/last                       50000 non-null  object
#  4   results/location/street/number          50000 non-null  int64
#  5   results/location/street/name            50000 non-null  object
#  6   results/location/city                   50000 non-null  object
#  7   results/location/state                  50000 non-null  object
#  8   results/location/country                50000 non-null  object
#  9   results/location/postcode               50000 non-null  object
#  10  results/location/coordinates/latitude   50000 non-null  float64
#  11  results/location/coordinates/longitude  50000 non-null  float64
#  12  results/location/timezone/offset        50000 non-null  object
#  13  results/location/timezone/description   50000 non-null  object
#  14  results/email                           50000 non-null  object
#  15  results/login/uuid                      50000 non-null  object
#  16  results/login/username                  50000 non-null  object
#  17  results/login/password                  50000 non-null  object
#  18  results/login/salt                      50000 non-null  object
#  19  results/login/md5                       50000 non-null  object
#  20  results/login/sha1                      50000 non-null  object
#  21  results/login/sha256                    50000 non-null  object
#  22  results/dob/date                        50000 non-null  object
#  23  results/dob/age                         50000 non-null  int64
#  24  results/registered/date                 50000 non-null  object
#  25  results/registered/age                  50000 non-null  int64
#  26  results/nat                             50000 non-null  object
# dtypes: float64(2), int64(3), object(22)
# memory usage: 10.3+ MB

# %%
df_users[df_users.duplicated()]
#no duplicates, 50000 unique users
# Out:
# Empty DataFrame
# Columns: [results/gender, results/name/title, results/name/first, results/name/last, results/location/street/number, results/location/street/name, results/location/city, results/location/state, results/location/country, results/location/postcode, results/location/coordinates/latitude, results/location/coordinates/longitude, results/location/timezone/offset, results/location/timezone/description, results/email, results/login/uuid, results/login/username, results/login/password, results/login/salt, results/login/md5, results/login/sha1, results/login/sha256, results/dob/date, results/dob/age, results/registered/date, results/registered/age, results/nat]
# Index: []

# %%
#drop results/ for all columns
df_users.columns = df_users.columns.str.replace('results/', '')

# %%
#drop useless columns
df_users = df_users.drop(columns = {'name/title', 'location/state', 'location/postcode','location/coordinates/latitude', 'location/coordinates/longitude', 'location/timezone/offset',
                                    'location/timezone/description', 'login/uuid', 'registered/date', 'registered/age', 'login/md5', 'login/sha1', 'nat'})

# %%
df_users = df_users.rename(columns = {'name/first': 'firstName', 'name/last': 'lastName', 'location/street/number': 'streetNumber', 'location/street/name': 'streetName',
                                      'location/city': 'city', 'location/country': 'country', 'login/username': 'username', 'login/password': 'password',  'login/salt': 'salt',
                                      'login/sha256': 'sha', 'dob/date': 'dateOfBirth', 'dob/age': 'age'})

# %%
df_users['dateOfBirth'] = pd.to_datetime(df_users['dateOfBirth']).dt.strftime('%Y-%m-%d')

# %%
#df_users['registered/date'] = pd.to_datetime(df_users['registered/date']).dt.strftime('%Y-%m-%d')
#il primo utente registrato è del 2002. La prima review è scritta nel 2003. 
#Volendo si potrebbe associare l'user rispettando che registered_date < review_date
#l'utente più piccolo è del 98, quindi al limite si registra all'età di 4 anni e scrive la prima recensione all'età di 5.
#soluzione: tolgo data di nascita dell'utente e tolgo la data di registrazione. Così rimane solo la data della review
#in alternativa bisogna pensare a far coesistere queste date associando per bene gli utenti alle recensioni

# %%
#create an admin column to identify the administrator user
#df_users['admin'] = ""
#df_users['admin'] = df_users['admin'].astype('bool')*1

# %%
#control if there are duplicate usernames
#because we don't want them
df_users.duplicated( subset = 'username').sum()
# Out:
# 2304

# %%
#so we enumerate duplicated username so to be each one unique
mask = df_users['username'].duplicated(keep=False)
df_users.loc[mask, 'username'] += df_users.groupby('username').cumcount().add(1).astype(str)

# %%
#create an _id column
df_users["_id"] = df_users.index + 1
df_users
# Out:
#        gender firstName   lastName  ...  dateOfBirth age    _id
# 0        male  Valentin    Pascual  ...   1998-07-25  23      1
# 1      female     Nilay   Zuidwijk  ...   1982-07-04  39      2
# 2      female     Bella    Johnson  ...   1993-08-20  28      3
# 3        male      Arlo      Lewis  ...   1949-05-11  72      4
# 4        male     سورنا      قاسمی  ...   1968-11-15  53      5
# ...       ...       ...        ...  ...          ...  ..    ...
# 49995    male     Byron  Carpenter  ...   1951-09-16  70  49996
# 49996  female     Susan     Murray  ...   1964-02-13  57  49997
# 49997  female     Iiris      Lakso  ...   1969-07-01  52  49998
# 49998    male   Vincent  Pelletier  ...   1964-07-03  57  49999
# 49999    male     Eelis     Nikula  ...   1971-12-09  50  50000
#
# [50000 rows x 15 columns]

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gender        50000 non-null  object
#  1   firstName     50000 non-null  object
#  2   lastName      50000 non-null  object
#  3   streetNumber  50000 non-null  int64
#  4   streetName    50000 non-null  object
#  5   city          50000 non-null  object
#  6   country       50000 non-null  object
#  7   email         50000 non-null  object
#  8   username      50000 non-null  object
#  9   password      50000 non-null  object
#  10  salt          50000 non-null  object
#  11  sha           50000 non-null  object
#  12  dateOfBirth   50000 non-null  object
#  13  age           50000 non-null  int64
#  14  _id           50000 non-null  int64
# dtypes: int64(3), object(12)
# memory usage: 5.7+ MB

# %% [markdown]
# # Add userId and username to df_reviews

# %%
#create a temporary df sample from df_users (need to execute Users_csv.csv section)
df = df_users.sample(n=70000, replace = True)
df = df.reset_index()

# %%
#ensuring _id column mantains dtype
df["_id"] = df["_id"].astype('Int64')

# %%
#add _id column to each review
df_reviews = df_reviews.join(df._id)

# %%
df_reviews
# Out:
#              asin  ...    _id
# 0      B0000SX2UC  ...  35345
# 1      B0000SX2UC  ...   9590
# 2      B0000SX2UC  ...   5765
# 3      B0000SX2UC  ...  22701
# 4      B0000SX2UC  ...   3078
# ...           ...  ...    ...
# 67981  B081H6STQQ  ...   4366
# 67982  B081H6STQQ  ...  19541
# 67983  B081H6STQQ  ...   7928
# 67984  B081TJFVCJ  ...  26009
# 67985  B0825BB7SG  ...  34787
#
# [67944 rows x 6 columns]

# %%
df_users
# Out:
#        gender firstName   lastName  ...  dateOfBirth age    _id
# 0        male  Valentin    Pascual  ...   1998-07-25  23      1
# 1      female     Nilay   Zuidwijk  ...   1982-07-04  39      2
# 2      female     Bella    Johnson  ...   1993-08-20  28      3
# 3        male      Arlo      Lewis  ...   1949-05-11  72      4
# 4        male     سورنا      قاسمی  ...   1968-11-15  53      5
# ...       ...       ...        ...  ...          ...  ..    ...
# 49995    male     Byron  Carpenter  ...   1951-09-16  70  49996
# 49996  female     Susan     Murray  ...   1964-02-13  57  49997
# 49997  female     Iiris      Lakso  ...   1969-07-01  52  49998
# 49998    male   Vincent  Pelletier  ...   1964-07-03  57  49999
# 49999    male     Eelis     Nikula  ...   1971-12-09  50  50000
#
# [50000 rows x 15 columns]

# %%
#thanks to userId we merge with df_users to add just the username
df_reviews = pd.merge(df_reviews, df_users, on = ['_id'])

# %%
#rename the _id column
df_reviews = df_reviews.rename(columns = {"_id": "userId"})

# %%
#drop useless columns for the df_reviews
df_reviews = df_reviews.drop(columns = {'gender', 'firstName', 'lastName', 'streetNumber', 'streetName', 'city', 'country',
                                        'email', 'password', 'salt', 'sha', 'dateOfBirth', 'age', })

# %%
df_reviews
# Out:
#              asin  rating  ... userId            username
# 0      B0000SX2UC       3  ...  35345        happyswan675
# 1      B07C6FCC8G       5  ...  35345        happyswan675
# 2      B07H7SBBWQ       5  ...  35345        happyswan675
# 3      B0000SX2UC       1  ...   9590        tinysnake155
# 4      B0000SX2UC       5  ...   5765        happyswan421
# ...           ...     ...  ...    ...                 ...
# 67939  B081H6STQQ       4  ...   4830       sadostrich418
# 67940  B081H6STQQ       1  ...  22162      orangegoose429
# 67941  B081H6STQQ       5  ...  33092    beautifulfish800
# 67942  B081H6STQQ       5  ...   4366   whitebutterfly113
# 67943  B081H6STQQ       5  ...  19541  ticklishpeacock941
#
# [67944 rows x 7 columns]

# %% [markdown]
# # Add brand_id to df_items

# %%
#as I need the brand_id, the df_items became this
df_items = pd.merge(df_brands, df_items)
df_items
# Out:
#      brand_id  ...                                          phoneName
# 0           1  ...  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1           1  ...                  Nokia 1680 Black Phone (T-Mobile)
# 2           1  ...  Nokia C3 Prepaid GoPhone (AT&T) with $30 Airti...
# 3           1  ...             Nokia Lumia 900 Black Factory Unlocked
# 4           1  ...                 Nokia Lumia 920, Black 32GB (AT&T)
# ..        ...  ...                                                ...
# 711       106  ...  Google - Pixel 3a with 64GB Memory Cell Phone ...
# 712       106  ...  Google - Pixel 3a XL with 64GB Memory Cell Pho...
# 713       106  ...  Google Pixel 3a XL Verizon Just Black, 64GB (R...
# 714       106  ...      Google Pixel 4 - Just Black - 64GB - Unlocked
# 715       106  ...  Google Pixel 3a G202G with 64GB Memory Cell Ph...
#
# [716 rows x 4 columns]

# %% [markdown]
# # Add phoneId to df_items

# %%
df_items
# Out:
#      brand_id  ...                                          phoneName
# 0           1  ...  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1           1  ...                  Nokia 1680 Black Phone (T-Mobile)
# 2           1  ...  Nokia C3 Prepaid GoPhone (AT&T) with $30 Airti...
# 3           1  ...             Nokia Lumia 900 Black Factory Unlocked
# 4           1  ...                 Nokia Lumia 920, Black 32GB (AT&T)
# ..        ...  ...                                                ...
# 711       106  ...  Google - Pixel 3a with 64GB Memory Cell Phone ...
# 712       106  ...  Google - Pixel 3a XL with 64GB Memory Cell Pho...
# 713       106  ...  Google Pixel 3a XL Verizon Just Black, 64GB (R...
# 714       106  ...      Google Pixel 4 - Just Black - 64GB - Unlocked
# 715       106  ...  Google Pixel 3a G202G with 64GB Memory Cell Ph...
#
# [716 rows x 4 columns]

# %%
df_devices
# Out:
#        brand_id           phoneName  ... batteryType phoneId
# 0             1          Nokia 3210  ...      Li-Ion       1
# 1             1          Nokia 5110  ...       Li-Po       2
# 2             1          Nokia 6110  ...       Li-Po       3
# 3             1          Nokia 6130  ...       Li-Po       4
# 4             1          Nokia 6150  ...       Li-Po       5
# ...         ...                 ...  ...         ...     ...
# 10628        98            vivo S7t  ...       Li-Po   10629
# 10629         6     Motorola Edge S  ...       Li-Po   10630
# 10630        62     ZTE Blade X1 5G  ...      Li-Ion   10631
# 10631        10     Sony Xperia Pro  ...       Li-Po   10632
# 10632         4  Samsung Galaxy A02  ...       Li-Po   10633
#
# [10633 rows x 16 columns]

# %%
df_items['phoneName_new'] = ""

pd.options.mode.chained_assignment = None


for j in range(len(df_items.index)):
    nameArray = df_items['phoneName'][j].split(" ")
    if len(nameArray) >= 5:
        for i in range(5):
            if nameArray[i].endswith(","):
                nameArray[i] = nameArray[:-1]
    elif len(nameArray) >= 4:
        for i in range(4):
            if nameArray[i].endswith(","):
                nameArray[i] = nameArray[:-1]
    else:
        for i in range(3):
            if nameArray[i].endswith(","):
                nameArray[i] = nameArray[:-1]

    if len(nameArray) >= 5:
        for i in range(len(df_devices.index)):
            if (df_devices['phoneName'][i].startswith(
                f"{nameArray[0]} {nameArray[1]} {nameArray[2]} {nameArray[3]} {nameArray[4]}")):
                df_items['phoneName_new'][j] = df_devices['phoneName'][i]
    if len(nameArray) >= 4:
        for i in range(len(df_devices.index)):
            if ((df_devices['phoneName'][i].startswith(f"{nameArray[0]} {nameArray[1]} {nameArray[2]} {nameArray[3]}")
                 and len(df_items['phoneName_new'][j]) == 0)):
                df_items['phoneName_new'][j] = df_devices['phoneName'][i]
    if len(nameArray) >= 3:
        for i in range(len(df_devices.index)):
            if ((df_devices['phoneName'][i].startswith(f"{nameArray[0]} {nameArray[1]} {nameArray[2]}")
                 and len(df_items['phoneName_new'][j]) == 0)):
                print(df_devices['phoneName'][i])
                df_items['phoneName_new'][j] = df_devices['phoneName'][i]
    if len(nameArray) >= 2:
        for i in range(len(df_devices.index)):
            if ((df_devices['phoneName'][i].startswith(f"{nameArray[0]} {nameArray[1]}")
                 and len(df_items['phoneName_new'][j]) == 0)):
                df_items['phoneName_new'][j] = df_devices['phoneName'][i]
    for i in range(len(df_devices.index)):
        if ((df_devices['phoneName'][i].startswith(f"{nameArray[0]}")
            and len(df_items['phoneName_new'][j]) == 0)):
            df_items['phoneName_new'][j] = df_devices['phoneName'][i]
# Out:
# Nokia Lumia 900 AT&T
# Nokia Lumia 822
# Nokia Lumia 920
# Nokia Lumia 925
# Nokia Lumia 520
# Nokia Lumia 520
# Nokia Lumia 928
# Nokia Lumia 635
# Nokia Lumia 530
# Nokia Lumia 630
# Nokia Lumia 928
# Microsoft Lumia 950
# Nokia 3310 3G
# Nokia 9 PureView
# Nokia 3310 3G
# Samsung Galaxy S4 CDMA
# Samsung Galaxy Prevail
# Samsung Galaxy S4 CDMA
# Samsung Galaxy Note N7000
# Samsung Galaxy S4 CDMA
# Samsung Galaxy S5
# Samsung Galaxy Mega 5.8 I9150
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy S4 CDMA
# Samsung Galaxy S4 CDMA
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy Note N7000
# Samsung Galaxy J5
# Samsung Galaxy S6
# Samsung Galaxy S5
# Samsung Galaxy Note N7000
# Samsung Galaxy S6
# Samsung Galaxy S4 CDMA
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S7
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S5
# Samsung Galaxy S6
# Samsung Galaxy S7
# Samsung Galaxy J3 (2016)
# Samsung Galaxy J1
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S6
# Samsung Galaxy S7
# Samsung Galaxy S6
# Samsung Galaxy S7
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy J7
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S8+
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S8+
# Samsung Galaxy S8+
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S8+
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy J7
# Samsung Galaxy S6
# Samsung Galaxy S8
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy J3 (2016)
# Samsung Galaxy S8
# Samsung Galaxy J3 (2016)
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy J3 (2016)
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S8
# Samsung Galaxy Note8
# Samsung Galaxy S8
# Samsung Galaxy S7
# Samsung Galaxy Note N7000
# Samsung Galaxy S8+
# Samsung Galaxy S8+
# Samsung Galaxy S8+
# Samsung Galaxy S8+
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S8
# Samsung Galaxy S8
# Samsung Galaxy S7
# Samsung Galaxy S7
# Samsung Galaxy S9
# Samsung Galaxy S9
# Samsung Galaxy S6
# Samsung Galaxy S6
# Samsung Galaxy S9
# Samsung Galaxy S9
# Samsung Galaxy S9
# Samsung Galaxy S9+
# Samsung Galaxy S9+
# Samsung Galaxy S9
# Samsung Galaxy S7
# Samsung Galaxy S9
# Samsung Galaxy S9+
# Samsung Galaxy S9
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy S8+
# Samsung Galaxy A30
# Samsung Galaxy S8+
# Samsung Galaxy J6
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy Note9
# Samsung Galaxy S7
# Samsung Galaxy J7
# Samsung Galaxy Note N7000
# Samsung Galaxy J8
# Samsung Galaxy Note N7000
# Samsung Galaxy Note9
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy S8
# Samsung Galaxy Note9
# Samsung Galaxy S8
# Samsung Galaxy S9
# Samsung Galaxy Note N7000
# Samsung Galaxy S9
# Samsung Galaxy S9
# Samsung Galaxy S9
# Samsung Galaxy S9
# Samsung Galaxy Note N7000
# Samsung Galaxy S8+
# Samsung Galaxy S8
# Samsung Galaxy J7
# Samsung Galaxy S6
# Samsung Galaxy Note N7000
# Samsung Galaxy Note N7000
# Samsung Galaxy J7
# Samsung Galaxy Note N7000
# Samsung Galaxy A50
# Samsung Galaxy J3 (2016)
# Samsung Galaxy S9+
# Samsung Galaxy Note N7000
# Samsung Galaxy J3 (2016)
# Samsung Galaxy S10+
# Samsung Galaxy S10+
# Samsung Galaxy Note9
# Samsung Galaxy S9+
# Samsung Galaxy Note8
# Samsung Galaxy S10+
# Samsung Galaxy S10e
# Samsung Galaxy S10e
# Samsung Galaxy S10e
# Samsung Galaxy S10+
# Samsung Galaxy S10+
# Samsung Galaxy S10+
# Samsung Galaxy S10e
# Samsung Galaxy S10+
# Samsung Galaxy S10e
# Samsung Galaxy S10+
# Samsung Galaxy A30
# Samsung Galaxy A10
# Samsung Galaxy A10
# Samsung Galaxy A6 (2018)
# Samsung Galaxy Note N7000
# Samsung Galaxy A10
# Samsung Galaxy M10
# Samsung Galaxy A50
# Samsung Galaxy M20
# Samsung Galaxy Note N7000
# Samsung Galaxy A70
# Samsung Galaxy A40
# Samsung Galaxy A50
# Samsung Galaxy A50
# Samsung Galaxy A70
# Samsung Galaxy A50
# Samsung Galaxy A50
# Samsung Galaxy Note N7000
# Samsung Galaxy A70
# Samsung Galaxy Note N7000
# Samsung Galaxy S7
# Samsung Galaxy A20
# Samsung Galaxy A10
# Samsung Galaxy A10
# Samsung Galaxy Note N7000
# Samsung Galaxy S10e
# Samsung Galaxy S10+
# Samsung Galaxy S10e
# Samsung Galaxy S10e
# Samsung Galaxy S10+
# Samsung Galaxy S10+
# Samsung Galaxy S10+
# Samsung Galaxy S10+
# Samsung Galaxy Note N7000
# Samsung Galaxy A20
# Samsung Galaxy J2
# Samsung Galaxy S10+
# Samsung Galaxy A80
# Samsung Galaxy Note N7000
# Samsung Galaxy A80
# Samsung Galaxy A20
# Samsung Galaxy A70
# Samsung Galaxy A10
# Samsung Galaxy A70
# Samsung Galaxy A50
# Samsung Galaxy A20
# Samsung Galaxy A50
# Samsung Galaxy A50
# Samsung Galaxy Note N7000
# Samsung Galaxy S9
# Samsung Galaxy A10s
# Samsung Galaxy Note N7000
# Samsung Galaxy S10+
# Samsung Galaxy S10e
# Samsung Galaxy A50
# Samsung Galaxy Note N7000
# Samsung Galaxy A20s
# Motorola Moto G
# Motorola Moto X
# Motorola DROID Turbo
# Motorola Moto E Dual SIM
# Motorola Droid Turbo 2
# Motorola Droid Turbo 2
# Motorola DROID Turbo
# Motorola Moto Z2 Play
# Motorola Moto X4
# Motorola Moto G6
# Motorola Moto Z3 Play
# Motorola Moto Z3 Play
# Motorola Moto X
# Motorola Moto G7
# Motorola Moto G7
# Motorola One Vision
# Motorola One Action
# Motorola One Action
# Motorola Moto E5
# Motorola Moto E6
# Motorola One Zoom
# Sony Xperia Z2
# Sony Xperia Z3 Compact
# Sony Xperia X
# Sony Xperia XZ
# Sony Xperia XZ
# Sony Xperia XA1 Ultra
# Sony Xperia L1
# Sony Xperia XZ1 Compact
# Sony Xperia XZ2
# Sony Xperia XZ2
# Sony Xperia XZ3
# Sony Xperia 10
# Sony Xperia 5
# Sony Xperia 10
# Apple iPad Air
# Apple iPhone 7
# Apple iPhone 7
# Apple iPhone 7
# Apple iPhone 7
# Apple iPhone 7
# Apple iPhone 8 Plus
# Apple iPhone 7
# Apple iPhone 7
# Apple iPad 2 Wi-Fi
# Apple iPad Air
# Apple iPhone 8 Plus
# Apple iPhone 7
# Apple iPad Pro 12.9 (2015)
# Apple iPhone 8 Plus
# Apple iPhone XS
# Apple iPhone 11 Pro Max
# Huawei Nexus 6P
# Huawei P Smart+ 2019
# Huawei Mate 20 lite
# Huawei Mate 20 lite
# Huawei Y9 Prime (2019)
# Xiaomi Redmi S2 (Redmi Y2)
# Xiaomi Pocophone F1
# Xiaomi Redmi 6A
# Xiaomi Redmi 7
# Xiaomi Redmi Note
# Xiaomi Redmi Note
# Xiaomi Redmi 7
# Xiaomi Redmi 7
# Xiaomi Mi 9
# Xiaomi Mi 9
# Xiaomi Mi 9T
# Xiaomi Redmi 7A
# Xiaomi Mi A3
# Xiaomi Mi A3
# Xiaomi Mi A3
# Xiaomi Mi A3
# Xiaomi Redmi 8A
# Xiaomi Redmi Note
# OnePlus 7 Pro
# OnePlus 7 Pro
# Google Pixel XL
# Google Pixel XL
# Google Pixel XL
# Google Pixel XL
# Google Pixel 2 XL
# Google Pixel 2 XL
# Google Pixel 2 XL
# Google Pixel 2 XL
# Google Pixel XL
# Google Pixel 3
# Google Pixel 2 XL
# Google Pixel 3
# Google Pixel 4 XL
# Google Pixel 3a

# %%
df_devices
# Out:
#        brand_id           phoneName  ... batteryType phoneId
# 0             1          Nokia 3210  ...      Li-Ion       1
# 1             1          Nokia 5110  ...       Li-Po       2
# 2             1          Nokia 6110  ...       Li-Po       3
# 3             1          Nokia 6130  ...       Li-Po       4
# 4             1          Nokia 6150  ...       Li-Po       5
# ...         ...                 ...  ...         ...     ...
# 10628        98            vivo S7t  ...       Li-Po   10629
# 10629         6     Motorola Edge S  ...       Li-Po   10630
# 10630        62     ZTE Blade X1 5G  ...      Li-Ion   10631
# 10631        10     Sony Xperia Pro  ...       Li-Po   10632
# 10632         4  Samsung Galaxy A02  ...       Li-Po   10633
#
# [10633 rows x 16 columns]

# %%
df_items
# Out:
#      brand_id  ...         phoneName_new
# 0           1  ...
# 1           1  ...    Nokia 1680 classic
# 2           1  ...       Nokia C3 (2010)
# 3           1  ...  Nokia Lumia 900 AT&T
# 4           1  ...       Nokia Lumia 800
# ..        ...  ...                   ...
# 711       106  ...        Google Pixel C
# 712       106  ...        Google Pixel C
# 713       106  ...    Google Pixel 3a XL
# 714       106  ...     Google Pixel 4 XL
# 715       106  ...       Google Pixel 3a
#
# [716 rows x 5 columns]

# %%
#drop the old phone name column
df_items = df_items.drop(columns = {'phoneName'})

# %%
#rename the new phone name column in order to be the same as phoneName in df_devices
df_items = df_items.rename(columns = {'phoneName_new': 'phoneName'})

# %%
##finally add the phoneId to df_items_final
#merge thanks to the common columns phoneName and brand_id
df_items = pd.merge(df_items, df_devices, on = ['phoneName', 'brand_id'])
#look that from 716 here we have 687 rows
#that's right because in df_items_final there are 27 rows really without phoneName
#2 rows are dropped during the merge because brand_id and phoneName didn't match

# %%
#drop columns we don't need to merge than with df_reviews
df_items = df_items.drop(columns = {'brand_id', 'picture', 'released_at', 'dimensions', 'os', 'storage', 'displaySize', 'displayResolution', 'cameraPixels', 'videoPixels', 'ram', 'chipset', 'batterySize', 'batteryType'})

# %%
df_items
# Out:
#       brand        asin             phoneName  phoneId
# 0     Nokia  B001GQ3DJM    Nokia 1680 classic     2311
# 1     Nokia  B004MK9VLS       Nokia C3 (2010)     3228
# 2     Nokia  B00836Y6B2  Nokia Lumia 900 AT&T     4229
# 3     Nokia  B00A2V7BA4       Nokia Lumia 800     4194
# 4     Nokia  B00A2V7ULY       Nokia Lumia 800     4194
# ..      ...         ...                   ...      ...
# 682  Google  B07JVDQP47        Google Pixel 3     9199
# 683  Google  B07ND4ZN2X        Google Pixel 3     9199
# 684  Google  B07YBHNTSK    Google Pixel 3a XL     9625
# 685  Google  B07YMNLXL3     Google Pixel 4 XL     9830
# 686  Google  B07ZP9ZWFM       Google Pixel 3a     9347
#
# [687 rows x 4 columns]

# %% [markdown]
# # Reviews

# %% [markdown]
# First dataset: contains all the reviews associated each one to their item, thanks to asin amazon code, taken from amazon.com

# %%
df_items
# Out:
#       brand        asin             phoneName  phoneId
# 0     Nokia  B001GQ3DJM    Nokia 1680 classic     2311
# 1     Nokia  B004MK9VLS       Nokia C3 (2010)     3228
# 2     Nokia  B00836Y6B2  Nokia Lumia 900 AT&T     4229
# 3     Nokia  B00A2V7BA4       Nokia Lumia 800     4194
# 4     Nokia  B00A2V7ULY       Nokia Lumia 800     4194
# ..      ...         ...                   ...      ...
# 682  Google  B07JVDQP47        Google Pixel 3     9199
# 683  Google  B07ND4ZN2X        Google Pixel 3     9199
# 684  Google  B07YBHNTSK    Google Pixel 3a XL     9625
# 685  Google  B07YMNLXL3     Google Pixel 4 XL     9830
# 686  Google  B07ZP9ZWFM       Google Pixel 3a     9347
#
# [687 rows x 4 columns]

# %%
df_reviews
# Out:
#              asin  rating  ... userId            username
# 0      B0000SX2UC       3  ...  35345        happyswan675
# 1      B07C6FCC8G       5  ...  35345        happyswan675
# 2      B07H7SBBWQ       5  ...  35345        happyswan675
# 3      B0000SX2UC       1  ...   9590        tinysnake155
# 4      B0000SX2UC       5  ...   5765        happyswan421
# ...           ...     ...  ...    ...                 ...
# 67939  B081H6STQQ       4  ...   4830       sadostrich418
# 67940  B081H6STQQ       1  ...  22162      orangegoose429
# 67941  B081H6STQQ       5  ...  33092    beautifulfish800
# 67942  B081H6STQQ       5  ...   4366   whitebutterfly113
# 67943  B081H6STQQ       5  ...  19541  ticklishpeacock941
#
# [67944 rows x 7 columns]

# %%
#merge the two dataset thanks to the common column asin
Reviews = pd.merge(df_items, df_reviews)

# %%
#drop some columns in order to uniform data for the data modeling
#we don't need anymore brand attribute here
Reviews = Reviews.drop(columns = {'brand'})

# %%
#rename columns to respect data modeling indications
Reviews = Reviews.rename(columns = {'asin': '_id', 'userId': 'userId', 'review_title': 'title', 'rating': 'rating', 'review_date':'dateOfReview', 'review_body': 'body'})

# %%
#rename columns to respect data modeling indications and to have the right datatypes when uploading data on MongoDB
#Reviews = Reviews.rename(columns = {'asin': '_id.string()', 'phoneId': 'phoneId.string()', 'phoneName': 'phoneName.string()' 'userId': 'userId.string()', 'review_title': 'title.string()', 'rating': 'rating.int()', 'review_date':'dateOfReview.date()', 'review_body': 'body.string()'})

# %%
#use the _id column as index
Reviews = Reviews.set_index('_id')

# %%
Reviews
#here we have 65487 rows and not 67944
#because doing the cleaning 4 asin values are being cancelled in df_items and so reviews with that asin are not merged.
#also 29 phoneName aren't matched between df_items and df_devices 
#so we have many reviews for each product, identified by a unique asin code, phoneId and userId
# Out:
#                      phoneName  phoneId  ...  userId            username
# _id                                      ...
# B001GQ3DJM  Nokia 1680 classic     2311  ...   40343          sadwolf249
# B001GQ3DJM  Nokia 1680 classic     2311  ...   30845           bigcat258
# B001GQ3DJM  Nokia 1680 classic     2311  ...    8729    beautifulbear772
# B004MK9VLS     Nokia C3 (2010)     3228  ...   48190  orangebutterfly895
# B004MK9VLS     Nokia C3 (2010)     3228  ...   11238       angrykoala904
# ...                        ...      ...  ...     ...                 ...
# B07YMNLXL3   Google Pixel 4 XL     9830  ...   14120     happygorilla883
# B07YMNLXL3   Google Pixel 4 XL     9830  ...   15412    crazyladybug6381
# B07YMNLXL3   Google Pixel 4 XL     9830  ...   43516        crazyswan859
# B07ZP9ZWFM     Google Pixel 3a     9347  ...    3421         tinyfish577
# B07ZP9ZWFM     Google Pixel 3a     9347  ...   45947      crazysnake2462
#
# [65487 rows x 8 columns]

# %%
#convert the df to csv format in order to be loaded on mongodb
#Reviews.to_csv('/content/drive/MyDrive/UNIPI AIDE/Large scale and multistructured databases/Workgroup project/LSMSD group 24/Data/Reviews.csv')

# %%
#Reviews.to_json('/content/drive/MyDrive/UNIPI AIDE/Large scale and multistructured databases/Workgroup project/LSMSD group 24/Data/Reviews.json')
# ValueError: DataFrame index must be unique for orient='columns'.

# %% [markdown]
# # Phones

# %% [markdown]
# Second dataset: contains all the smartphones taken from gsmarena.com

# %%
df_brands
# Out:
#      brand_id       brand
# 0           1       Nokia
# 1           2     alcatel
# 2           3     Benefon
# 3           4     Samsung
# 4           5  Mitsubishi
# ..        ...         ...
# 111       112      Realme
# 112       113     Infinix
# 113       114       Tecno
# 114       115         TCL
# 115       116   Fairphone
#
# [116 rows x 2 columns]

# %%
df_devices
# Out:
#        brand_id           phoneName  ... batteryType phoneId
# 0             1          Nokia 3210  ...      Li-Ion       1
# 1             1          Nokia 5110  ...       Li-Po       2
# 2             1          Nokia 6110  ...       Li-Po       3
# 3             1          Nokia 6130  ...       Li-Po       4
# 4             1          Nokia 6150  ...       Li-Po       5
# ...         ...                 ...  ...         ...     ...
# 10628        98            vivo S7t  ...       Li-Po   10629
# 10629         6     Motorola Edge S  ...       Li-Po   10630
# 10630        62     ZTE Blade X1 5G  ...      Li-Ion   10631
# 10631        10     Sony Xperia Pro  ...       Li-Po   10632
# 10632         4  Samsung Galaxy A02  ...       Li-Po   10633
#
# [10633 rows x 16 columns]

# %%
#merge hanks to brand_id
Phones = pd.merge(df_brands, df_devices)

# %%
# now we don't need anymore brand_id used to merge brands and devices so we drop it
Phones = Phones.drop(columns = {'brand_id'})

# %%
#we need to take just the release year of the phone, so we take just numbers of that string
Phones.released_at = Phones.released_at.str.extract('(\d+)')

# %%
#we analyze if we collect strange value for the release date
Phones.released_at.unique()
# Out:
# array(['1999', '1998', '1996', '2000', nan, '1997', '1995', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2017', '2016',
#        '2019', '2018', '2020', '2021', '1994', '2', '20078'], dtype=object)

# %%
#we view and then drop that rows with released date 2 or 20078
Phones[Phones.released_at == "2"]
# Out:
#          brand       phoneName  ... batteryType phoneId
# 2855  Ericsson  Ericsson R520m  ...        NiMH     192
#
# [1 rows x 16 columns]

# %%
Phones[Phones.released_at == "20078"]
# Out:
#            brand              phoneName  ... batteryType phoneId
# 5087  BlackBerry  BlackBerry Pearl 8130  ...      Li-Ion    3887
#
# [1 rows x 16 columns]

# %%
#before running this and the next piece of code
#reload again the previous part without extracting numbers from released_at column.
#snippet useful to see the right release date
#Phones[Phones.phoneName == "Ericsson R520m"]
#code commented because is exploratory, otherwise will interrupt the run

# %%
#we assume the real release date is 2007
#df_devices[df_devices.phoneName == "BlackBerry Pearl 8130"]
#code commented because is exploratory, otherwise will interrupt the run

# %%
#adjust these two values manually
Phones['released_at'][2855] = 2001

# %%
Phones['released_at'][5087] = 2007

# %%
#drop NaN values now present in released_at column
Phones = Phones.dropna()

# %%
#rename column because it refers just to the release year
Phones = Phones.rename(columns = {'phoneId': '_id', 'released_at': 'releaseYear', 'phoneName': 'name', 'dimensions': 'body' })

# %%
#rename columns to be compliant with data modeling and specify datatype for import of csv on MongoDB
#Phones = Phones.rename(columns = {'phoneId': '_id.string()', 'brand': 'brand.string()', 'phoneName': 'name.string()', 'picture': 'picture.string()', 'releaseYear': 'releaseYear.date()', 'dimensions': 'body.string()',
#                                  'os': 'os.string()', 'storage': 'storage.string()', 'displaySize': 'displaySize.string()', 'displayResolution': 'displayResolution.string()', 'cameraPixels': 'cameraPixels.string()',
#                                  'videoPixels': 'videoPixels.string()', 'ram': 'ram.string()', 'chipset': 'chipset.string()', 'batterySize': 'batterySize.string()', 'batteryType': 'batteryType.string()'})

# %%
#use the _id column as index
Phones = Phones.set_index('_id')

# %%
Phones
# Out:
#            brand          name  ... batterySize batteryType
# _id                             ...
# 1          Nokia    Nokia 3210  ...      &nbsp;      Li-Ion
# 2          Nokia    Nokia 5110  ...    600 mAh        Li-Po
# 3          Nokia    Nokia 6110  ...    600 mAh        Li-Po
# 4          Nokia    Nokia 6130  ...    600 mAh        Li-Po
# 5          Nokia    Nokia 6150  ...    600 mAh        Li-Po
# ...          ...           ...  ...         ...         ...
# 10600        TCL     TCL 20 SE  ...   5000 mAh        Li-Po
# 10601        TCL  TCL NxtPaper  ...   5500 mAh       Li-Ion
# 10602        TCL   TCL Tab 10s  ...   8000 mAh        Li-Po
# 9996   Fairphone  Fairphone 3+  ...   3040 mAh       Li-Ion
# 10323  Fairphone   Fairphone 3  ...   3040 mAh       Li-Ion
#
# [10332 rows x 15 columns]

# %%
#convert the df to csv format in order to be loaded on mongodb
#Phones.to_csv('/content/drive/MyDrive/UNIPI AIDE/Large scale and multistructured databases/Workgroup project/LSMSD group 24/Data/Phones.csv')

# %%
#Phones.to_json('/content/drive/MyDrive/UNIPI AIDE/Large scale and multistructured databases/Workgroup project/LSMSD group 24/Data/Phones.json')

# %% [markdown]
# # Users

# %% [markdown]
# Third dataset: contains all the users created from randomuser.me

# %%
#take the user dataset and assign it to a new df
Users = df_users

# %%
#we dro the password for the user
Users = Users.drop(columns = {'password'})

# %%
#rename columns for data modeling compatibility and specify datatypes for MongoDB
#Users = Users.rename(columns = {'_id': '_id.string()', 'gender': 'gender.string()', 'firstName': 'firstName.string()', 'lastName': 'lastName.string()', 'streetNumber': 'streetNumber.string()',
#                                'streetName': 'streetName.string()', 'city': 'city.string()', 'country': 'country.string()', 'email': 'email.string()', 'username': 'username.string()', 'salt': 'salt.string()', 'sha': 'sha.string()',
#                                'dateOfBirth': 'dateOfBirth.date()', 'age': 'age.int()'})

# %%
#set the _id column as index
Users = Users.set_index('_id')

# %%
Users
# Out:
#        gender firstName  ... dateOfBirth  age
# _id                      ...
# 1        male  Valentin  ...  1998-07-25   23
# 2      female     Nilay  ...  1982-07-04   39
# 3      female     Bella  ...  1993-08-20   28
# 4        male      Arlo  ...  1949-05-11   72
# 5        male     سورنا  ...  1968-11-15   53
# ...       ...       ...  ...         ...  ...
# 49996    male     Byron  ...  1951-09-16   70
# 49997  female     Susan  ...  1964-02-13   57
# 49998  female     Iiris  ...  1969-07-01   52
# 49999    male   Vincent  ...  1964-07-03   57
# 50000    male     Eelis  ...  1971-12-09   50
#
# [50000 rows x 13 columns]

# %%
#convert the df to csv format in order to be loaded on mongodb
#Users.to_csv('/content/drive/MyDrive/UNIPI AIDE/Large scale and multistructured databases/Workgroup project/LSMSD group 24/Data/Users.csv')

# %%
#convert the df to json format in order to be loaded on mongodb
#Users.to_json('/content/drive/MyDrive/UNIPI AIDE/Large scale and multistructured databases/Workgroup project/LSMSD group 24/Data/Users.json')
